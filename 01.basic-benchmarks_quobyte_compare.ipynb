# %%
# %matplotlib inline
import pandas as pd
import matplotlib.pyplot as plt

# %%
def load_benchmark_and_annotate(filename, n_query, n_against):
    df = pd.read_csv(filename, sep='\t')
    df['n_query'] = int(n_query)
    df['n_against'] = int(n_against)
    
    return df

load_benchmark_and_annotate('benchmarks/a_100_vs_a.txt', 100, 10000)
# Out:
#            s    h:m:s   max_rss   max_vms   max_uss   max_pss  io_in  io_out  \
# 0  1347.0233  0:22:27  12910.21  15135.63  13073.72  13073.72   0.01    0.14
#
#    mean_load  cpu_time  n_query  n_against
# 0     2762.7  37225.36      100      10000

# %%
query_line = [ load_benchmark_and_annotate(f"benchmarks/a_{x}_vs_a.txt", x, 10000) for x in range(100, 1000, 100) ]

#query_line.append(load_benchmark_and_annotate('benchmarks/a_vs_a.txt', 1000, 10000))
query_line_df = pd.concat(query_line)
query_line_df
# Out:
#            s    h:m:s   max_rss   max_vms   max_uss   max_pss     io_in  \
# 0  1347.0233  0:22:27  12910.21  15135.63  13073.72  13073.72      0.01
# 0  1291.4875  0:21:31  14541.96  18260.40  14601.04  14601.05      0.01
# 0  1454.4474  0:24:14  16348.15  18954.26  16429.44  16429.44      0.02
# 0  1551.7362  0:25:51  14438.77  16864.46  14666.07  14666.08      0.02
# 0  1603.6622  0:26:43  18893.50  21000.83  18968.33  18968.33      0.03
# 0  1696.6006  0:28:16  17783.73  19868.45  17888.35  17888.35      0.03
# 0  1610.4366  0:26:50  16855.73  19042.42  16989.04  16989.04      0.04
# 0  1770.2948  0:29:30  16316.45  19000.11  16440.92  16440.92      0.04
# 0  1806.3763  0:30:06  16779.61  19569.78  16286.82  16286.82  95967.58
#
#    io_out  mean_load  cpu_time  n_query  n_against
# 0    0.14    2762.70  37225.36      100      10000
# 0    0.24    3044.57  39323.17      200      10000
# 0    0.31    2828.24  41136.09      300      10000
# 0    0.40    2751.87  42702.26      400      10000
# 0    0.48    2802.76  44947.46      500      10000
# 0    0.59    2755.67  46753.81      600      10000
# 0    0.70    3032.36  48835.22      700      10000
# 0    0.85    2863.60  50694.71      800      10000
# 0    0.97    2889.70  52198.87      900      10000

# %%
quo_query_line = [ load_benchmark_and_annotate(f"benchmarks.quobyte/a_{x}_vs_a.txt", x, 10000) for x in range(100, 1000, 100) ]
quo_query_line_df = pd.concat(quo_query_line)
quo_query_line_df
# Out:
#            s    h:m:s   max_rss   max_vms   max_uss   max_pss     io_in  \
# 0  1162.8157  0:19:22  18997.52  23878.00  19488.38  19488.66      0.01
# 0  1412.3448  0:23:32  14810.07  17239.73  14174.27  14174.55      0.01
# 0  1313.0555  0:21:53  17390.10  21158.68  17320.14  17320.41      0.02
# 0  1528.5183  0:25:28  13448.81  15992.88  13542.36  13542.63      0.02
# 0  1505.2579  0:25:05  13926.41  17138.85  13939.65  13939.92      0.03
# 0  1473.2980  0:24:33  19966.12  23967.04  20016.52  20016.78      0.03
# 0  1723.1636  0:28:43  16750.52  21506.70  16766.94  16767.20      0.04
# 0  1740.7366  0:29:00  13400.32  16234.74  13229.82  13230.06      0.04
# 0  1742.6810  0:29:02  16575.49  20774.84  16739.16  16739.44  12070.06
#
#    io_out  mean_load  cpu_time  n_query  n_against
# 0     0.0    2888.42  33587.05      100      10000
# 0     0.0    2487.27  35129.06      200      10000
# 0     0.0    2773.60  36418.75      300      10000
# 0     0.0    2473.59  37809.40      400      10000
# 0     0.0    2614.97  39362.13      500      10000
# 0     0.0    2794.10  41165.41      600      10000
# 0     0.0    2463.08  42442.27      700      10000
# 0     0.0    2509.93  43691.62      800      10000
# 0     0.0    2612.59  45529.02      900      10000

# %%
against_line = [ load_benchmark_and_annotate(f"benchmarks/a_vs_a_{x}.txt", 1000, x) for x in range(1000, 10000, 1000) ]
#against_line.append(load_benchmark_and_annotate('benchmarks/a_vs_a.txt', 1000, 10000))
against_line_df = pd.concat(against_line)
against_line_df
# Out:
#            s    h:m:s   max_rss   max_vms   max_uss   max_pss  io_in  io_out  \
# 0   154.1568  0:02:34   8026.29   8707.47   8042.18   8042.25   0.07    0.11
# 0   269.0769  0:04:29   8977.02   9920.71   8961.81   8961.88   0.13    0.25
# 0   354.2737  0:05:54  11786.54  13038.87  11863.02  11863.11   0.20    0.36
# 0   478.0915  0:07:58  13964.38  15485.38  14074.45  14074.53   0.26    0.48
# 0   704.6193  0:11:44  15294.20  18001.37  15028.22  15028.30   0.33    0.64
# 0  1073.2904  0:17:53  12150.98  14048.74  12201.99  12201.99   0.39    0.73
# 0  1269.1121  0:21:09  15887.25  17586.37  15507.43  15507.43   0.46    0.79
# 0  1419.2742  0:23:39  16026.34  18511.11  16068.09  16068.09   0.52    0.89
# 0  1576.3652  0:26:16  16715.54  19374.40  16759.83  16759.83   7.45    1.00
#
#    mean_load  cpu_time  n_query  n_against
# 0    2112.52   3256.75     1000       1000
# 0    2450.90   6594.63     1000       2000
# 0    2943.38  10428.58     1000       3000
# 0    3003.24  14358.91     1000       4000
# 0    2722.32  19182.34     1000       5000
# 0    2635.62  28288.41     1000       6000
# 0    2923.52  37104.07     1000       7000
# 0    3018.64  42844.40     1000       8000
# 0    3052.70  48122.82     1000       9000

# %%
quo_against_line = [ load_benchmark_and_annotate(f"benchmarks.quobyte/a_vs_a_{x}.txt", 1000, x) for x in range(1000, 10000, 1000) ]
#against_line.append(load_benchmark_and_annotate('benchmarks/a_vs_a.txt', 1000, 10000))
quo_against_line_df = pd.concat(quo_against_line)
quo_against_line_df
# Out:
#            s    h:m:s   max_rss   max_vms   max_uss   max_pss  io_in  io_out  \
# 0   237.4116  0:03:57   7684.28   8800.33   7802.29   7802.59   0.00     0.0
# 0   366.2607  0:06:06   9817.54  10801.36   9873.40   9873.68   0.12     0.0
# 0   470.3574  0:07:50  10213.26  11778.20  10169.59  10169.86   0.19     0.0
# 0   614.2592  0:10:14  13133.09  16322.82  13194.47  13194.76   0.25     0.0
# 0  1006.9718  0:16:46  15449.10  17748.61  15016.04  15016.34   0.31     0.0
# 0  1066.2326  0:17:46  13807.07  16115.25  13897.41  13897.72   0.38     0.0
# 0  1105.0427  0:18:25  15063.78  17894.73  15197.97  15198.23   0.44     0.0
# 0  1238.7524  0:20:38  17603.96  20879.96  17490.12  17490.42   0.50     0.0
# 0  1429.6253  0:23:49  15088.23  17541.75  14948.63  14948.93   0.61     0.0
#
#    mean_load  cpu_time  n_query  n_against
# 0    1627.00   3862.69     1000       1000
# 0    2141.66   7844.31     1000       2000
# 0    2601.59  12237.12     1000       3000
# 0    2798.82  17192.36     1000       4000
# 0    2256.98  22727.47     1000       5000
# 0    2525.65  26929.75     1000       6000
# 0    2813.19  31087.26     1000       7000
# 0    2941.14  36433.50     1000       8000
# 0    2825.72  40397.22     1000       9000

# %%
#fig = plt.figure()
fig, axs = plt.subplots(1, 2, figsize=(12, 4))

ax = axs[0]
ax.plot(query_line_df.n_query, query_line_df['s'] / 60, '-p', label='orig')
ax.plot(quo_query_line_df.n_query, quo_query_line_df['s'] / 60, '-p', label='quobyte')

ax.axis(xmin=0, ymin=0, ymax=35)
ax.set_xlabel('num queries')
ax.set_ylabel('walltime (m)')
ax.set_title('varying number of queries (10k subjects)')
ax.legend(loc='lower right')


ax = axs[1]
ax.plot(against_line_df.n_against, against_line_df['s'] / 60, '-p', label='orig')
ax.plot(quo_against_line_df.n_against, quo_against_line_df['s'] / 60, '-p', label='quobyte')

ax.axis(xmin=0, ymin=0, ymax=35)
ax.set_xlabel('num subject datasets')
ax.set_ylabel('walltime (m)')
ax.set_title('varying number of subjects (1000 queries)')
ax.legend(loc='lower right')

plt.savefig('subsample_benchmarks.svg')

# %%
def load_benchmark_replicate(filename, ident):
    df = pd.read_csv(filename, sep='\t')
    df['ident'] = ident
    
    return df

replicates_df = [ load_benchmark_replicate(f"benchmarks/a_vs_{x}.txt", x) for x in ('a','b','c','d','e')]
#query_line.append(load_benchmark_and_annotate('benchmarks/a_vs_a.txt', 1000, 10000))
replicates_df = pd.concat(replicates_df)
replicates_df
# Out:
#            s    h:m:s   max_rss   max_vms   max_uss   max_pss     io_in  \
# 0  1394.1251  0:23:14  16106.77  18410.19  16167.91  16167.94  95974.41
# 0  1394.1750  0:23:14  17553.49  20057.43  17685.95  17685.99  94003.57
# 0  1357.7237  0:22:37  18257.87  20041.38  18277.77  18277.80  91280.15
# 0  1505.0091  0:25:05  16107.48  19187.17  16137.28  16137.32  93738.74
# 0  1596.4828  0:26:36  14046.44  15868.38  14061.43  14061.46  91948.11
#
#    io_out  mean_load  cpu_time ident
# 0    1.14    2914.11  40626.79     a
# 0    1.16    2771.80  38643.81     b
# 0    1.01    2794.07  37936.37     c
# 0    1.02    2605.24  39209.39     d
# 0    0.96    2367.13  37791.57     e

# %%
quo_replicates_df = [ load_benchmark_replicate(f"benchmarks.quobyte/a_vs_{x}.txt", x) for x in ('a','b','c','d','e')]
#query_line.append(load_benchmark_and_annotate('benchmarks/a_vs_a.txt', 1000, 10000))
quo_replicates_df = pd.concat(quo_replicates_df)
quo_replicates_df
# Out:
#            s    h:m:s   max_rss   max_vms   max_uss   max_pss     io_in  \
# 0  1828.5562  0:30:28  17199.63  19372.52  17137.26  17137.49  95859.33
# 0  1736.2214  0:28:56  20809.34  24031.92  20838.29  20838.55  92243.98
# 0  1664.0652  0:27:44  17074.38  19697.34  17159.77  17160.03  91210.98
# 0  1649.0302  0:27:29  16548.58  20109.86  16397.11  16397.37  93627.83
# 0  1613.8850  0:26:53  19621.16  25938.22  19731.92  19732.19  91417.85
#
#    io_out  mean_load  cpu_time ident
# 0     0.0    2552.00  46664.91     a
# 0     0.0    2637.59  45794.45     b
# 0     0.0    2665.93  44363.13     c
# 0     0.0    2758.07  45481.58     d
# 0     0.0    2771.49  44728.82     e

# %%
fig, axs = plt.subplots(1, 2, figsize=(18, 4))

ax = axs[0]
ax.boxplot(replicates_df.s)
ax.set_title('time (s)')

ax = axs[1]
ax.boxplot(quo_replicates_df.s)

ax.set_title('time (s) - quobyte')

replicates_df['m'] = replicates_df['s'] / 60.0

print(f"mean (minutes) {replicates_df.m.mean()}, std {replicates_df.m.std()}")
# Out:
# mean (minutes) 24.158385666666664, std 1.650659128576706

# %%
fig, axs = plt.subplots(1, 2, figsize=(18, 4))

ax = axs[0]
ax.boxplot(replicates_df.max_rss)
ax.set_title('max RSS (mb)')

ax = axs[1]
ax.boxplot(quo_replicates_df.max_rss)
ax.set_title('max RSS (mb) - quobyte')

print(f"mean {replicates_df.max_rss.mean()}, std {replicates_df.max_rss.std()}")
# Out:
# mean 16414.41, std 1619.5661713403376

# %%
fig, axs = plt.subplots(1, 2, figsize=(18, 4))

ax = axs[0]
ax.boxplot(replicates_df.io_in)
ax.set_title('I/O in (mb)')

ax = axs[1]
ax.boxplot(quo_replicates_df.io_in)
ax.set_title('I/O in (mb) - quobyte')

print(f"mean {replicates_df.io_in.mean()}, std {replicates_df.io_in.std()}")
# Out:
# mean 93388.996, std 1851.2003899578276

# %%
def load_threads_benchmark_and_annotate(filename, n_threads):
    df = pd.read_csv(filename.format(threads=n_threads), sep='\t')
    df['threads'] = n_threads
    
    return df


x = [ load_threads_benchmark_and_annotate(f'benchmarks/a_vs_a_1000_t{t}.txt', t) for t in (4,8,16,64) ]
x.append(load_threads_benchmark_and_annotate(f'benchmarks/a_vs_a_1000.txt', 32))

threads_df = pd.concat(x).sort_values(by='threads')

x2 = [ load_threads_benchmark_and_annotate(f'benchmarks.quobyte/a_vs_a_1000_t{t}.txt', t) for t in (4,8,16,64) ]
x2.append(load_threads_benchmark_and_annotate(f'benchmarks.quobyte/a_vs_a_1000.txt', 32))

quo_threads_df = pd.concat(x2).sort_values(by='threads')

# %%
threads_df
# Out:
#           s    h:m:s   max_rss   max_vms   max_uss   max_pss    io_in  io_out  \
# 0  814.4291  0:13:34   2246.58   2380.33   2243.58   2244.08    89.14    0.11
# 0  484.0369  0:08:04   2661.74   3352.14   2661.75   2662.25  1189.09    0.11
# 0  329.2121  0:05:29   6144.40   7038.87   6169.71   6170.21  7404.52    0.10
# 0  154.1568  0:02:34   8026.29   8707.47   8042.18   8042.25     0.07    0.11
# 0  268.0256  0:04:28  11262.78  13753.96  11263.22  11263.51  8681.05    0.09
#
#    mean_load  cpu_time  threads
# 0     341.55   2782.05        4
# 0     649.08   3142.19        8
# 0    1137.80   3746.52       16
# 0    2112.52   3256.75       32
# 0    1430.49   3833.95       64

# %%
quo_threads_df
# Out:
#           s    h:m:s   max_rss   max_vms   max_uss   max_pss    io_in  io_out  \
# 0  730.2899  0:12:10   2834.26   3305.06   2859.93   2860.22    20.21     0.0
# 0  555.4759  0:09:15   3092.03   3682.67   3123.50   3124.25    23.80     0.0
# 0  322.4711  0:05:22   5016.30   5616.88   4961.63   4962.34    15.32     0.0
# 0  178.0744  0:02:58  12812.36  15743.64  12812.48  12812.76  1346.62     0.0
# 0  237.4116  0:03:57   7684.28   8800.33   7802.29   7802.59     0.00     0.0
#
#    mean_load  cpu_time  threads
# 0     371.60   2713.87        4
# 0     643.01   3571.32        8
# 0    1140.63   3677.28       16
# 0    2190.40   3900.65       64
# 0    1627.00   3862.69       32

# %%
#fig = plt.figure()
fig, axs = plt.subplots(1, 3, figsize=(18, 4))

ax = axs[0]
ax.plot(threads_df.threads, threads_df.s, '-p', label='observed times')
ax.plot(quo_threads_df.threads, quo_threads_df.s, '-p', label='observed times (quobyte)')

ax.plot([4, 8, 16, 32, 64], [484 * 2, 484, 484 / 2, 484 / 4, 484 / 8], '--', label='perfect scaling')
ax.axis(xmin=0, ymin=0)
ax.set_xlabel('num threads')
ax.set_ylabel('walltime (s)')
ax.set_title('walltime')
ax.legend(loc='upper right')

ax = axs[1]
ax.plot(threads_df.threads, threads_df.cpu_time, '-p')
ax.plot(quo_threads_df.threads, quo_threads_df.cpu_time, '-p')

ax.axis(xmin=0, ymin=0, ymax=4000)
ax.set_xlabel('num threads')
ax.set_ylabel('total CPU time (s)')
ax.set_title('total compute')

ax = axs[2]
ax.plot(threads_df.threads, threads_df.max_rss, '-p')
ax.plot(quo_threads_df.threads, quo_threads_df.max_rss, '-p')

ax.axis(xmin=0, ymin=0)
ax.set_xlabel('num threads')
ax.set_ylabel('max RSS (GB)')
ax.set_title('memory usage')

plt.savefig('basic_benchmarks.svg')
